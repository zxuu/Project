# %%
f=open('E:/A文本标注/My_Data/Chinese/NER/Military/军事报道.txt', encoding='utf-8')

# %%
i=0
for line in f:
    if line !='':
        print(line)
        print('.........')
        i = i + 1
        if i>6:
            break
# Out:
# 韩媒：韩江原道代表团将访问河北 为平昌冬奥宣传造势
#
# .........
# 　　【环球网报道 记者 李婷婷】据韩联社12月5日报道，韩国江原道知事崔文洵将率领由企业家和高校代表组成的代表团于6-8日访问中国河北省，为2018平昌冬奥会宣传造势，同时与河北省就两地经济、旅游、高校等领域的交流合作交换意见。　　据报道，代表团将向中方提议两地结缘、加强经济合作、在冬奥期间运营襄阳至石家庄包机等事宜，并希望中方为宣传冬奥旅游产品等提供配合。代表团将重点宣传平昌冬奥和冬奥旅游产品，开设旅游宣传馆让访客体验冬季运动，积极宣传中国游客免签入韩15天的新措施。　　报道说，届时，两地高校和经济界人士也将展开交流。韩国江原道大学、翰林大学将与河北地质大学、河北医科大学举办先进医疗系统和未来人才交流座谈会，推进学校发展和吸引优秀外国留学生。代表团经济界人士将同韩中地域经济协会等有关机构就经贸合作交流进行磋商。
#
# .........
#
#
# .........
# 李克强就西班牙巴塞罗那发生货车冲撞人群恐怖袭击事件向西班牙首相拉霍伊致慰问电
#
# .........
# 国务院总理李克强8月18日就西班牙巴塞罗那市中心发生货车冲撞人群恐怖袭击事件向西班牙首相拉霍伊致慰问电。李克强在慰问电中代表中国政府向遇难者表示沉痛哀悼，向其家属致以诚挚慰问，愿伤者早日康复。李克强表示，中方坚定支持西班牙打击恐怖主义和维护国家安全的努力，愿同包括西班牙在内的各国一道，共同为促进世界的和平与安全作出贡献。（新华社北京8月18日电）
#
# .........
#
#
# .........
# 美特种部队助菲军 剿马拉维武装分子
#
# .........

# %%
j = 0
file_write = open('data1.txt', 'a', encoding='utf-8')
with open('E:/A文本标注/My_Data/Chinese/NER/Military/军事报道.txt', 'r', encoding='utf-8') as f:
    while j<10000:
        data = f.readline().strip()
        if data != '':
            data_split = data.split('。')
            for line in data_split:
                print(line)
                file_write.writelines(line.strip())
                file_write.writelines('\n')
                j = j+1
        
    
file_write.close()
f.close()
# Out:
# 陈虎：隐形无人机可破解攻击航母情报信息问题
# 编者按：7月12日，英国航空航天系统公司公布了该公司研制的第一款高科技隐形无人机雷电之神
# 这款飞行从外型上来看酷似电影中的太空飞行器，据英国方面介绍，可以实现洲际远程打击
# 那么这款无人机到底有多厉害？是不是像它的外表那样神乎其神？未来无人机在战场上将发挥什么作用？本周《陈虎点兵》与您一起关注
# 　　本月12日，英国首次公布了最新研发的一款高科技无人驾驶隐身战机雷电之神
# 从外观上来看，这款无人机很有未来派的味道，全身融合，有点像飞碟，进气道也放在了飞机背部，一看就是具有很好的隐身性能
# 按照英国方面公布的情况，这款无人机是耗资相当于14.6亿元人民币，用了4年时间研发出来的
#  　　雷电之神：大个头有大智慧　　目前关于这款无人机公布的信息还是比较含糊的，例如讲到了它的高速性能、洲际飞行能力，统统没有具体的数字
# 和现有或以前的一些无人机相比，这种无人机的特点主要有两个：　　第一，是高度的隐身
# 在此之前的无人战机也具备某种程度的隐身性能，但像雷电之神这样，全面运用隐身技术，从外形上看就具有高度隐形能力的无人机还是第一个
# 　　第二， 雷电之神的个头比较大
# 按照英国方面公布的数字，这架飞机的机长是11.35米，高3.98米，翼展将近10米，这个大小大概相当于英国的鹰式教练机和我们国产的L15高级教练机
# 按照英国人的说法这款无人机是世界最大，实际上肯定不是世界最大，因为它的尺寸比美国的全球鹰要小了不少，但在现有的无人机里，也算是大家伙了
# 大个头有大智慧，有大力量
# 它的尺寸决定了它具有较强的飞行能力和装载能力
# 按照英国人的说法，这款无人机具有洲际飞行能力，在飞行控制方面，可以通过卫星实现洲际飞行控制，这是在无人机控制，特别是远程控制上突破性的进展
# 这种飞机还配备了两个弹仓，可以进行攻击任务
#  　　新一代无人机逐渐走向战场　　这些年来，无人机我们讲过不少，世界上推出的各种各样的无人机花样翻新，不断更新换代
# 为什么雷电之神值得我们去关注呢？我认为雷电之神本身的意义有限，但它标志着新一代的无人机开始逐渐走向战场，可能会掀起一个无人机的新时代
# ...

# %%
j = 0
i = 0
# file_write = open('data1.txt', 'a', encoding='utf-8')
for line in  open('E:\A文本标注\My_Data\English\Docs\ALLSides超党派检测.txt'.replace('\\', '/'), 'r', encoding='utf-8'):
    if line.strip() != '':
        # print(line.strip())
        # i = i+1
        # if i>10:
        #     break
        j = j + len(line.split('.'))


print(j)
    
# file_write.close()
# f.close()
# Out:
# 6977699
